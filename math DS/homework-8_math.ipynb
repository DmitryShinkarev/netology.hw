# %% [markdown]
# ### Задание 1
#
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import math
import random


# %matplotlib inline

# %% [markdown]
# В нём имелось в виду построение 3-х разных графиков, на каждом 5 распределений одного типа с разными параметрами, чтобы получить интуицию, на что влияют параметры.
# На 1-м графике 5 нормальных распределений с разными парами (матожидание, дисперсия), на 2-м 5 экспоненциальных с разными lambda и тд.

# %%
num = 1

while num < 6:
    
    mu = random.uniform(2.0,4.0)
    sigma = random.uniform(0.1,0.6)
    print(mu, sigma)

    # зададим нормально распределенную случайную величину
    norm_rv = sts.norm(loc=mu, scale=sigma)

    # сгенерируем 10 значений
    norm_rv.rvs(size=10)

    x = np.linspace(0,6,100)
    pdf = norm_rv.pdf(x)
    plt.plot(x, pdf)
    
    plt.ylabel('$f(x)$')
    plt.xlabel('$x$')
    num += 1
    
plt.show()
# Out:
# 3.8976794477434074 0.5262723367338931
# 3.4342826035985676 0.1930140365587595
# 3.498163020454491 0.3179620968742717
# 2.9086710241380613 0.142300404217416
# 3.0441682405367247 0.36183876927624237

# %%
# Экспоненциальное
num = 1

while num < 6:
    
    lam = random.uniform(0.1,1.0)
    expon_rv = sts.expon(lam)
    expon_rv.rvs(10)

    e = np.linspace(0,5,1000)
    pdfe = expon_rv.pdf(e)

    plt.plot(e, pdfe)
    plt.ylabel('$f(x)$')
    plt.xlabel('$x$')
    num += 1

plt.show()

# %%
# Стьюдента
num = 1

while num < 6:
    
    n = random.uniform(20,100)
    t_rv = sts.t(n)
    t_rv.rvs(10)
    t = np.linspace(0,10,1000)
    pdft = t_rv.pdf(t-5)

    plt.plot(t, pdft)
    plt.ylabel('$f(x)$')
    plt.xlabel('$x$')
    num += 1

plt.show()

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Непрерывная случайная величина задана плотностью распределения:
# $$ f(\xi) = C, x \in [0;5];f(\xi) = 0, x \notin [0;5]$$
# Найдите C, математическое ожидание $\xi$ а также вероятность попадания $\xi$ в отрезок $[3.5;7]$, т.е. $P(3.5<\xi<7)$.

# %% [markdown]
# C = 0.2
#
# M(e) = 2,5
#
# P(3,5 < e < 7) = $0,2*5-0.2*3.5 = 0.3$

# %% [markdown]
# ### Задание 3
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
inform = - (54/86*math.log(52/86,2)+28/86*math.log(28/86,2)+4/86*math.log(4/86,2))

# %%
print(inform)
# Out:
# 1.188710305897076

# %%
inform = - (28/84*math.log(28/84,2)+28/84*math.log(28/84,2)+28/84*math.log(28/84,2))
print(inform)
# Out:
# 1.584962500721156

# %%
inform = - (1/2*math.log(1/2,2)+1/2*math.log(1/2,2))
print(inform)
# Out:
# 1.0

# %%
inform = - (math.log(3,2))
print(inform)
# Out:
# -1.5849625007211563
